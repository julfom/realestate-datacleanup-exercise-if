# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset, and it was downloaded using web scraping techniques. The data contains registers from **Fotocasa** which is one of the most popular real estate websites in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and in no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# This CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# TODO
max_price = ds['price'].max()
max_price_row = ds[ds['price'] == max_price]
max_price_address = max_price_row['address'].iloc[0]
print(f"The house at {max_price_address} is the most expensive and its price is {max_price} USD")
# Out:
# The house at El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is the cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO
min_price = ds['price'].min()
min_price_row = ds[ds['price'] == min_price]
min_price_address = min_price_row['address'].iloc[0]
print(f"The house at {min_price_address} is the the cheapest and its price is {min_price} USD")
# Out:
# The house at Parla is the the cheapest and its price is 0 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The biggest house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smallest house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO
max_surface = ds['surface'].max()
max_surface_row = ds[ds['surface'] == max_surface]
max_surface_address = max_surface_row['address'].iloc[0]
print(f"The biggest house is located at {max_surface_address} and its surface is {max_surface} square meters")

min_surface = ds['surface'].min()
min_surface_row = ds[ds['surface'] == min_surface]
min_surface_address = min_surface_row['address'].iloc[0]
print(f"The smallest house is located at {min_surface_address} and its surface is {min_surface} square meters")
# Out:
# The biggest house is located at Sevilla la Nueva and its surface is 249000.0 square meters
# The smallest house is located at Calle Amparo,  Madrid Capital and its surface is 15.0 square meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the names of the populations with a comma as a separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
import numpy as np
populations=np.array(ds.loc[:,"level5"])
print(*populations, sep = ", ")
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Fuenlabrada, Arganda del Rey, Las Rozas de Madrid, Las Rozas de Madrid, Las Rozas de Madrid, Las Rozas de Madrid,  Madrid Capital,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero,  Madrid Capital,  Madrid Capital,  Madrid Capital, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes,  Madrid Capital, Rivas-vaciamadrid, Alpedrete,  Madrid Capital,  Madrid Capital,  Madrid Capital, Móstoles,  Madrid Capital,  Madrid Capital,  Madrid Capital, San Fernando de Henares, Coslada,  Madrid Capital, Becerril de la Sierra,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Alcalá de Henares,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Pinto,  Madrid Capital,  Madrid Capita
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`True` or `False`) followed by the rows/cols that contains NAs.

# %%
# TODO
ds.isna()
total_false_count = (~ds.isna()).sum().sum()

print(f"The Dataset has {total_false_count} N/A entries")
# Out:
# The Dataset has 501705 N/A entries

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions.

# %%
# TODO
ds_cleaned = ds.dropna()
print(ds_cleaned)
ds_cleaned.describe()
ds.describe()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level4, level5, level6, level7, level8, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, zipCode, customZone]
# Index: []
#
# [0 rows x 37 columns]
#          Unnamed: 0  id_realEstates  phone_realEstate         rooms  \
# count  15335.000000    1.533500e+04      1.454100e+04  14982.000000
# mean    7668.000000    1.524371e+08      9.143423e+08      3.231611
# std     4426.977524    2.277286e+06      7.516036e+06      1.393106
# min        1.000000    1.221584e+08      8.762742e+08      1.000000
# 25%     3834.500000    1.519456e+08      9.113649e+08      2.000000
# 50%     7668.000000    1.532413e+08      9.121841e+08      3.000000
# ...

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value.

# %%
# TODO
import pandas as pd
import numpy as np
populations = ds[ds['address'] == "Arroyomolinos (Madrid)"]
lvl5_price = np.array(populations.loc[:,"price"])
print(*lvl5_price, sep = ", ")
level5_mean = np.mean(lvl5_price)
print(f"The mean of prices is {level5_mean}")
# Out:
# 165338, 251646, 225000, 373000, 220000, 385000, 195000, 349000, 285000, 429900, 199900, 201900, 204900, 344900, 349000, 279900, 249900, 335000, 282000, 377500, 355000, 335000, 249000, 289000, 332500, 315000, 356000, 190000, 0, 349000, 420000, 380000, 222000, 220000, 580000, 309000, 285000, 285000, 285000, 285000, 285000, 285000, 339000, 339000, 357000, 360000, 204900, 204900, 229900, 229900, 229900, 349000, 234900, 249900, 339900, 0, 365000, 329900, 299000, 204900, 309000, 360000, 390000, 309990, 349000, 190000, 289000, 490000, 462000
# The mean of prices is 294656.14492753625

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6))
plt.hist(lvl5_price, bins=30, edgecolor='black', alpha=0.7)
plt.title('Histogram of Prices in Arroyomolinos (Madrid)')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
#Most requent prices are around 280,000 and 360,000

# %% [markdown]
# Most requent prices are around 280,000 and 360,000.

# %% [markdown]
# #### Exercise 09. Are the average prices of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about them.

# %%
# TODO
import pandas as pd
valdemorillo = ds[ds['address'] == "Valdemorillo"]
valde_prices = valdemorillo['price'].dropna()
valde_average_price = valde_prices.mean()
print(f"The average price for entries with address 'Valdemorillo' is: {valde_average_price}")

galapagar = ds[ds['address'] == "Galapagar"]
gala_prices = galapagar['price'].dropna()
gala_average_price = gala_prices.mean()
print(f"The average price for entries with address 'Galapagar' is: {gala_average_price}")

if gala_average_price > valde_average_price:
    print('Average price of Galapagar is higher'),
else: print('Average price of Valdemorillo is higher')
# Out:
# The average price for entries with address 'Valdemorillo' is: 341452.8823529412
# The average price for entries with address 'Galapagar' is: 341757.1914893617
# Average price of Galapagar is higher

# %% [markdown]
# #### Exercise 10. Are the average prices per square meter (price/m2) of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about it.
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
# TODO
valdemorillo = ds[ds['address'] == "Valdemorillo"]
valde_prices_m = valdemorillo['price'].mean()
valde_surface_m = valdemorillo['surface'].mean()
valde_price_m2 = valde_prices_m / valde_surface_m
print(f"The average price per square meter at Valdemorillo is: {valde_price_m2} price/m2")

galapagar = ds[ds['address'] == "Galapagar"]
gala_prices_m = galapagar['price'].mean()
gala_surface_m = galapagar['surface'].mean()
gala_price_m2 = gala_prices_m / gala_surface_m
print(f"The average price per square meter at Galapagar is: {gala_price_m2} price/m2")

if gala_average_price > valde_average_price:
    print('Average price of Galapagar is higher'),
else: print('Average price of Valdemorillo is higher')
# Out:
# The average price per square meter at Valdemorillo is: 1152.0002778439314 price/m2
# The average price per square meter at Galapagar is: 1390.261581723131 price/m2
# Average price of Galapagar is higher

# %% [markdown]
# #### Exercise 11. Analyze the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot`, then write a conclusion about it.

# %%
# TODO: Code
gala_surface = galapagar['surface']
gala_prices = galapagar['price']

scat_df = pd.DataFrame({
    'x': gala_surface,
    'y': gala_prices
})
plt.xlabel('Surface')
plt.ylabel('Prices')
plt.title('Surface & Prices in Galapagar')
plt.scatter(scat_df['x'], scat_df['y'])
plt.figure(figsize=(10, 6))

plt.show()

# %% [markdown]
# The property price is proportional to its area.

# %% [markdown]
# #### Exercise 12. How many real estate agencies does the dataset contain? (★★☆)
#
# Print the obtained value.

# %%
# TODO
last_row = ds.iloc[-1]
last_agency_count = last_row['Unnamed: 0']
print(f"There are {last_agency_count} agencies")
# Out:
# There are 15335 agencies

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses.

# %%
# TODO

counts = ds['level5'].value_counts()

most_frequent_entry = counts.idxmax()
most_frequent_count = counts.max()
print(f"The most popular level 5 population is{most_frequent_entry}")
print(f"It appears {most_frequent_count} times.")
# Out:
# The most popular level 5 population is Madrid Capital
# It appears 6643 times.

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of Madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`.

# %%
# TODO
south_belt = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

sb_lvl5 = ds[ds["level5"].isin(south_belt)]
print(sb_lvl5.to_string())
#print(sb_lvl5)
# Out:
#        Unnamed: 0  id_realEstates  isNew                                 realEstate_name  phone_realEstate                                                                                                                                                                                                                 url_inmueble  rooms  bathrooms  surface    price                          date                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in Exercise 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: 
median_price = sb_lvl5['price'].median()
plt.figure(figsize=(6, 4)) 
plt.bar(['Median Price'], [median_price], color='skyblue')  
plt.xlabel('Metric') 
plt.ylabel('Price')  
plt.title('Median Price of South Belt Properties') 

plt.show()

# %% [markdown]
# THE MEDIAN PRICE IS 175,000.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in Exercise 14) (★★★)
#
# Print both values for each variable.

# %%
# TODO
mean_price = sb_lvl5['price'].mean()
mean_rooms = sb_lvl5['rooms'].mean()
mean_surface = sb_lvl5['surface'].mean()
mean_bathrooms = sb_lvl5['bathrooms'].mean()

variance_price = sb_lvl5['price'].var()
variance_rooms = sb_lvl5['rooms'].var()
variance_surface = sb_lvl5['surface'].var()
variance_bathrooms = sb_lvl5['bathrooms'].var()

print(f"Sample Mean of Price: {mean_price}")
print(f"Sample Mean of Rooms: {mean_rooms}")
print(f"Sample Mean of Surface Area: {mean_surface}")
print(f"Sample Mean of Bathrooms: {mean_bathrooms}")

print(f"Sample Variance of Price: {variance_price}")
print(f"Sample Variance of Rooms: {variance_rooms}")
print(f"Sample Variance of Surface Area: {variance_surface}")
print(f"Sample Variance of Bathrooms: {variance_bathrooms}")
# Out:
# Sample Mean of Price: 223094.48070562293
# Sample Mean of Rooms: 3.0177383592017737
# Sample Mean of Surface Area: 111.75222363405337
# Sample Mean of Bathrooms: 1.633221850613155
# Sample Variance of Price: 14921367508.04902
# Sample Variance of Rooms: 0.7188858892927542
# Sample Variance of Surface Area: 4263.051760316337
# Sample Variance of Bathrooms: 0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house in each population? You must use the subset obtained in Exercise 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population.

# %%
# TODO
max_prices = sb_lvl5.groupby('level5')['price'].max()
print(max_prices)
# Out:
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000
# Name: price, dtype: int64

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in Exercise 14) (★★★)
#
# For the normalization method, you can use the one you consider; there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot.
#
# Hint: You can help yourself by reviewing the *multihist* demo of Matplotlib.

# %%
# TODO
sb_lvl5['normalized_price'] = sb_lvl5.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

south_belt = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

plt.figure(figsize=(10, 6))

for population in south_belt:
    subset = sb_lvl5[sb_lvl5['level5'] == population]
    plt.hist(subset['normalized_price'], bins=20, alpha=0.5, label=population)


plt.title("Normalized Price Histograms for South Belt Populations")
plt.xlabel("Normalized Price")
plt.ylabel("Frequency")
plt.legend(loc='upper right')


plt.show()
# Out:
# /tmp/ipykernel_724/1588690770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_lvl5['normalized_price'] = sb_lvl5.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

# %% [markdown]
# Getafe properties prices are more variable than in any other south belt town.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
# TODO
sb_lvl5['pps'] = sb_lvl5['price'] / sb_lvl5['surface']


getafe = sb_lvl5[sb_lvl5['address'] == "Getafe"]
alcorcon = sb_lvl5[sb_lvl5['address'] == "Alcorcón"]

getafe_average_pps = getafe['pps'].mean()
alcorcon_average_pps = alcorcon['pps'].mean()

print(f"Average pps for Getafe: {getafe_average_pps}")
print(f"Average pps for Alcorcón: {alcorcon_average_pps}")
if alcorcon_average_pps > getafe_average_pps:
    print (f"Alcorcon average price per square meter is higher than Getafe")
# Out:
# Average pps for Getafe: 1921.8334775699416
# Average pps for Alcorcón: 2171.0596744534632
# Alcorcon average price per square meter is higher than Getafe
# /tmp/ipykernel_724/574151621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_lvl5['pps'] = sb_lvl5['price'] / sb_lvl5['surface']

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph. You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Make a scatter plot of each population using subplots.

# %%
plt.figure(figsize=(10, 6))
south_belt = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
colors = ['blue', 'green', 'red', 'purple']

plt.figure(figsize=(10, 6))

for population, color in zip(south_belt, colors):
    subset = sb_lvl5[sb_lvl5['level5'] == population]
    plt.scatter(subset['surface'], subset['price'], alpha=0.5, c=color, label=population)

plt.title("Scatter Plot of Price vs. Surface for South Belt")
plt.xlabel("Surface (square meters)")
plt.ylabel("Price")
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in Exercise 14) (★★★★)
#
# Execute the following cell, and then start coding in the next one. You must implement a simple code that transforms the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centered on (60 degrees latitude and -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Map centered on (60 degrees latitude and -2.2 degrees longitude)
#       4 # Latitude, longitude
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:46, in Bunch.__getattr__(self, key)
#      44     return self.__getitem__(key)
# ...

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
